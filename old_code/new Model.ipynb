# %%
from NutOptimizer import NutOptimizer
import pandas as pd
import numpy as np
import json
from pathlib import Path
from matplotlib import pyplot as plt
import time
from typing import List

# %%
start_time = time.time()

# %% [markdown]
# # Data Horizons Paper Models

# %%
conversion_factors = pd.read_csv('../data/FoodData_Central_csv_2022-04-28/food_calorie_conversion_factor.csv')
food_conversions = pd.read_csv('../data/FoodData_Central_csv_2022-04-28/food_nutrient_conversion_factor.csv')
conversions = conversion_factors.merge(food_conversions, left_on='food_nutrient_conversion_factor_id', right_on='id')

# %%
fp = Path('../Data Collection/guidelines/fdc_const.json')
dat_fp = Path('../brand new data/new_fdc_kroger_combined_per_serving.csv')
dat = pd.read_csv(dat_fp)
dat = dat.fillna(0)

rename_dict = {
               'Protein': 'Protein - g',
               'Carbohydrate, by difference': "Total Carbohydrate"
              }

dat = dat.rename(rename_dict, axis=1)

# Conversions: sugar from g to kcal, total lipid g to kcal, Fatty acids total saturated g to kcal, Vitamin A iu to mcg RAE
dat['Protein - cal'] = dat['Protein - g'] * 4 
dat['Carb - cal'] = dat['Total Carbohydrate'] * 4
dat['Total lipid (fat)'] *= 9
dat['Fatty acids, total saturated'] *= 9
dat['Sugars, total including NLEA'] *= 4
dat['Sugars, added'] *= 4
dat['Price per Serving'] = round(dat['Price'] / dat['No Servings'], 2)
pd.set_option('display.max_columns', 50)

# %%
# Clean up categories
cats = pd.read_csv('../data/categories.csv')

cats = cats[cats['Category'].isin(dat['branded_food_category'])]

def new_cat(row: pd.DataFrame):
    if pd.isna(row['Level 3 Categorization']):
        return row['Category']
    return row['Level 3 Categorization']

cats['Final Category'] = cats.apply(new_cat, axis=1)

cats_dict = {}
for idx, row in cats.iterrows():
    cats_dict[row['Category']] = row['Final Category']

# %%
# Add indicator columns for categories
categories = dat['branded_food_category'].unique()

for cat in categories:
    dat.loc[dat['branded_food_category'] == cat, cats_dict[cat]] = 1
    dat.loc[dat['branded_food_category'] == cat, 'final_category'] = cats_dict[cat]
    
dat = dat.fillna(0)
dat = dat[dat['Price'] != 0]
dat = dat.reset_index(drop=True)
    
# pd.set_option('display.max_columns', 250)
# dat.head()

# %%
# Add weights for optimization constraints
category_weights = ['Protein Foods', 'Grains']
for cat in category_weights:
    dat.loc[dat['final_category'] == cat, cat+'_wt_in_g'] = dat.loc[dat['final_category'] == cat, 'serving_size']
    
dat = dat.fillna(0)

# %%
# Drop Categories which we don't want
level_2_cats = cats[cats['Level 2'] == 'Include']['Category']

level_2_dat = dat[dat['branded_food_category'].isin(level_2_cats)]
level_2_dat = level_2_dat.reset_index(drop=True)

# %%
opt = NutOptimizer(data=dat)
opt.load_constraints_json(fp)

level_2_opt = NutOptimizer(data=level_2_dat)
level_2_opt.load_constraints_json(fp)

constraints = opt.get_models()
level_2_constraints = level_2_opt.get_models()

for name in constraints:
    if name not in ['F 31-50', 'M 31-50']:
        opt.remove_model(name)
        level_2_opt.remove_model(name)

# %% [markdown]
# ## Original Results - No Category Restrictions

# %%
pd.set_option('display.max_colwidth', 500)

# %%
# No category restrictions
opt.optimize_all('Price per Serving', verbose=False, var_type='INTEGER')
int_res = opt.get_all_results()
int_cost = opt.get_all_optimal_values('Price per Serving')

print("Original Data - F 31-50 - Integer Optimization")
original_integer_fem_res = round(opt.get_one_optimal_value("F 31-50", "Price per Serving"),2)
original_integer_male_res = round(opt.get_one_optimal_value("M 31-50", "Price per Serving"),2)
pd.DataFrame(int_res['F 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'Amount']]
# Out:
# Original Data - F 31-50 - Integer Optimization
#                  ID  \
# 3937   884395207721
# 4327    50000609307
# 6249   761720987490
# 7201   715141503494
# 7203   715141716825
# 7205   715141729283
# 7342    11110850058
# 10327   11110401014
# 10501   76808006490
#
#                                                                     Description  \
# 3937                                                     Sun Vista® Pinto Beans
# 4327   Carnation Breakfast Essentials Rich Milk Chocolate Nutritional Drink Mix
# 6249                                                            Mazola Corn Oil
# 7201                                            Eggland's Best Large White Eggs
# 7203                          Eggland's Best Cage Free Large Brown Organic Eggs
# 7205                                      Eggland's Best Extra Large White Eggs
# 7342                                                  Kroger® Spaghetti Noodles
# 10327                                              Kroger® Vitamin D Whole Milk
# 10501                                 Barilla® Whole Grain Thin Spaghetti Pasta
#
#           branded_food_category  Price per Serving  Amount
# 3937     Canned & Bottled Beans               0.03     2.0
# 4327           Breakfast Drinks               0.55     3.0
# 6249   Vegetable & Cooking Oils               0.07     1.0
# 7201     Eggs & Egg Substitutes               0.29     1.0
# 7203     Eggs & Egg Substitutes               0.50     1.0
# 7205     Eggs & Egg Substitutes               0.30     2.0
# 7342      Pasta by Shape & Type               0.12     2.0
# 10327                      Milk               0.20     2.0
# 10501     Pasta by Shape & Type               0.24     1.0

# %%
print("Original Data - M 31-50 - Integer Optimization")
pd.DataFrame(int_res['M 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'Amount']]
# Out:
# Original Data - M 31-50 - Integer Optimization
#                  ID  \
# 2154    72310010284
# 3937   884395207721
# 4327    50000609307
# 4423    11110881328
# 6249   761720987490
# 7201   715141503494
# 7205   715141729283
# 7342    11110850058
# 9518    41000119767
# 10327   11110401014
# 10498   76808006506
#
#                                                                     Description  \
# 2154     Bigelow® Blackberry Citrus Herbal Tea Caffeine Free Tea Bags plus Zinc
# 3937                                                     Sun Vista® Pinto Beans
# 4327   Carnation Breakfast Essentials Rich Milk Chocolate Nutritional Drink Mix
# 4423                                 Kroger® Sugar Free Hazelnut Coffee Creamer
# 6249                                                            Mazola Corn Oil
# 7201                                            Eggland's Best Large White Eggs
# 7205                                      Eggland's Best Extra Large White Eggs
# 7342                                                  Kroger® Spaghetti Noodles
# 9518                                              Lipton Raspberry Iced Tea Mix
# 10327                                              Kroger® Vitamin D Whole Milk
# 10498                                       Barilla® Whole Grain Linguine Pasta
#
#           branded_food_category  Price per Serving  Amount
# 2154                   Tea Bags               0.19     1.0
# 3937     Canned & Bottled Beans               0.03     3.0
# 4327           Breakfast Drinks               0.55     4.0
# 4423             Milk Additives               0.05     1.0
# 6249   Vegetable & Cooking Oils               0.07     2.0
# 7201     Eggs & Egg Substitutes               0.29     1.0
# 7205     Eggs & Egg Substitutes               0.30     2.0
# 7342      Pasta by Shape & Type               0.12     2.0
# 9518            Powdered Drinks               0.01     1.0
# 10327                      Milk               0.20     2.0
# 10498     Pasta by Shape & Type               0.24     1.0

# %%
level_2_opt.optimize_all('Price per Serving', verbose=False, var_type='INTEGER')
level_2_int_res = level_2_opt.get_all_results()
level_2_int_cost = level_2_opt.get_all_optimal_values('Price per Serving')

print("Level 2 Data - F 31-50 - Integer Optimization")
level2_integer_fem_res = round(level_2_opt.get_one_optimal_value("F 31-50", "Price per Serving"),2)
level2_integer_male_res = round(level_2_opt.get_one_optimal_value("M 31-50", "Price per Serving"),2)
pd.DataFrame(level_2_int_res['F 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'Amount']]
# Out:
# Level 2 Data - F 31-50 - Integer Optimization
#                 ID                                        Description  \
# 172   884912114709        Raisin Bran Whole Grain Wheat & Bran Cereal
# 267    21000604913               Kraft Singles American Cheese Slices
# 1502   11110051813                Good to Dough® Enriched White Bread
# 4583   29000073258                      Planters® Dry Roasted Peanuts
# 4681  715141716825  Eggland's Best Cage Free Large Brown Organic Eggs
# 4683  715141729283              Eggland's Best Extra Large White Eggs
# 4741   11110850058                          Kroger® Spaghetti Noodles
# 5006   71430009765                                       Dole Spinach
# 5390   34856121664              Welch's Value Size Mixed Fruit Snacks
# 6451   16000175815             Tasty™ Chicken Tikka Masala Dinner Kit
# 6759   11110613158               Kroger® Salted with Sea Salt Peanuts
# 6760   11110613196       Kroger® Spanish Salted with Sea Salt Peanuts
#
#                          branded_food_category  Price per Serving  Amount
# 172                                     Cereal               0.36     1.0
# 267                                     Cheese               0.21     1.0
# 1502                             Breads & Buns               0.05     1.0
# 4583  Popcorn, Peanuts, Seeds & Related Snacks               0.23     1.0
# 4681                    Eggs & Egg Substitutes               0.50     1.0
# 4683                    Eggs & Egg Substitutes               0.30     3.0
# 4741                     Pasta by Shape & Type               0.12     3.0
# 5006           Pre-Packaged Fruit & Vegetables               0.86     1.0
# 5390                                     Candy               0.22     3.0
# 6451                                    Cereal               0.60     1.0
# 6759  Popcorn, Peanuts, Seeds & Related Snacks               0.17     1.0
# 6760  Popcorn, Peanuts, Seeds & Related Snacks               0.17     1.0

# %%
print("Level 2 Data - M 31-50 - Integer Optimization")
pd.DataFrame(level_2_int_res['M 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'Amount']]
# Out:
# Level 2 Data - M 31-50 - Integer Optimization
#                 ID                                        Description  \
# 172   884912114709        Raisin Bran Whole Grain Wheat & Bran Cereal
# 1502   11110051813                Good to Dough® Enriched White Bread
# 2311   10700804273                           Zero King Size Candy Bar
# 4583   29000073258                      Planters® Dry Roasted Peanuts
# 4681  715141716825  Eggland's Best Cage Free Large Brown Organic Eggs
# 4683  715141729283              Eggland's Best Extra Large White Eggs
# 4741   11110850058                          Kroger® Spaghetti Noodles
# 5006   71430009765                                       Dole Spinach
# 5390   34856121664              Welch's Value Size Mixed Fruit Snacks
# 6451   16000175815             Tasty™ Chicken Tikka Masala Dinner Kit
# 6759   11110613158               Kroger® Salted with Sea Salt Peanuts
#
#                          branded_food_category  Price per Serving  Amount
# 172                                     Cereal               0.36     2.0
# 1502                             Breads & Buns               0.05     1.0
# 2311                                     Candy               0.01     1.0
# 4583  Popcorn, Peanuts, Seeds & Related Snacks               0.23     1.0
# 4681                    Eggs & Egg Substitutes               0.50     1.0
# 4683                    Eggs & Egg Substitutes               0.30     3.0
# 4741                     Pasta by Shape & Type               0.12     3.0
# 5006           Pre-Packaged Fruit & Vegetables               0.86     1.0
# 5390                                     Candy               0.22     3.0
# 6451                                    Cereal               0.60     1.0
# 6759  Popcorn, Peanuts, Seeds & Related Snacks               0.17     2.0

# %%
print(f'Original F 31-50 Integer: ${original_integer_fem_res}')
print(f'Original M 31-50 Integer: ${original_integer_male_res}')

print(f'Level 2 F 31-50 Integer: ${level2_integer_fem_res}')
print(f'Level 2 M 31-50 Integer: ${level2_integer_male_res}')
# Out:
# Original F 31-50 Integer: $4.05
# Original M 31-50 Integer: $4.45
# Level 2 F 31-50 Integer: $5.07
# Level 2 M 31-50 Integer: $5.23

# %%
original_baskets_df = pd.DataFrame()

df = pd.DataFrame(int_res['M 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'serving_size', 'Size', 'Amount']]
df['Model'] = 'Original Data - M 31-50 - Integer - No Category Constraints'
original_baskets_df = original_baskets_df.append(df)

df = pd.DataFrame(int_res['F 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'serving_size', 'Size', 'Amount']]
df['Model'] = 'Original Data - F 31-50 - Integer - No Category Constraints'
original_baskets_df = original_baskets_df.append(df)

df = pd.DataFrame(level_2_int_res['M 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'serving_size', 'Size', 'Amount']]
df['Model'] = 'Level 2 - M 31-50 - Integer - No Category Constraints'
original_baskets_df = original_baskets_df.append(df)

df = pd.DataFrame(level_2_int_res['F 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'serving_size', 'Size', 'Amount']]
df['Model'] = 'Level 2 - F 31-50 - Integer - No Category Constraints'
original_baskets_df = original_baskets_df.append(df)

# %% [markdown]
# ## Original Results with Category Constraints

# %%
include_mins = True
max_per_category = 2
cats = cats[cats['Level 2'] == 'Include']
cats['Final Category'].unique()
# Out:
# array(['Dairy', 'Soup', 'Vegetables', 'Breakfast',
#        'Other Frozen Desserts', 'Snacks', 'Grains', 'Side Dish',
#        'Dough Based Products / Meals', 'Protein Foods',
#        'Cooked & Prepared', 'Frozen Dinners & Entrees', 'Other Deli',
#        'Candy', 'Mexican Dinner Mixes', 'Chocolate', 'Pizza', 'Fruit',
#        'Frozen Bread & Dough', 'Entrees, Sides & Small Meals',
#        'Pizza Mixes & Other Dry Dinners', 'Prepared Wraps and Burittos',
#        'Prepared/Preserved Foods Variety Packs', 'Deli Salads',
#        'Prepared Subs & Sandwiches'], dtype=object)

# %%
def add_category_constraints(opt: NutOptimizer, add_min: bool, max_val: int):
    # Add any additional category constraints
    const_dict = {}
    if max_val is not None:
        for cat in cats['Final Category'].unique():
            # Add in any additional constraints here
            const_dict[cat] = max_val

#     del const_dict['0']
    del const_dict['Fruit'] # Don't put maxes on the categories that we are already placing mins on
    del const_dict['Vegetables']
    del const_dict['Dairy']
    
    
    for cat in const_dict:
        opt.update_constraint('F 31-50', cat, 'max', const_dict[cat])
        opt.update_constraint('M 31-50', cat, 'max', const_dict[cat])
    if add_min:
        
        opt.update_constraint('F 31-50', 'Protein Foods_wt_in_g', 'min', 142)
        opt.update_constraint('M 31-50', 'Protein Foods_wt_in_g', 'min', 170)

        opt.update_constraint('F 31-50', 'Vegetables', 'min', 2)
        opt.update_constraint('M 31-50', 'Vegetables', 'min', 3)

        opt.update_constraint('F 31-50', 'Fruit', 'min', 2)
        opt.update_constraint('M 31-50', 'Fruit', 'min', 3)

        opt.update_constraint('F 31-50', 'Dairy', 'min', 3)
        opt.update_constraint('M 31-50', 'Dairy', 'min', 3)

        opt.update_constraint('F 31-50', 'Grains_wt_in_g', 'min', 142)
        opt.update_constraint('M 31-50', 'Grains_wt_in_g', 'min', 170)

# %%
# Fruit: F min 2 servings, M min 3 servings
# Vegetables: F min 2 servings, M min 3 servings
# Grains: F min 5 oz (142 g), M min 7 oz (198 g)
# Protein Foods: F min 5 oz (142 g), M min 6 oz (170 g)
# Dairy: F min 3 servings, M min 3 servings

add_category_constraints(level_2_opt, include_mins, max_per_category)

# %%
level_2_opt.optimize_all('Price per Serving', verbose=False, var_type='INTEGER')
level_2_int_res = level_2_opt.get_all_results()
level_2_int_cost = level_2_opt.get_all_optimal_values('Price per Serving')

print("Level 2 Data - F 31-50 - Integer Optimization - With Category Constraints")
level2_integer_fem_res = round(level_2_opt.get_one_optimal_value("F 31-50", "Price per Serving"),2)
level2_integer_male_res = round(level_2_opt.get_one_optimal_value("M 31-50", "Price per Serving"),2)
pd.DataFrame(level_2_int_res['F 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'Amount']]
# Out:
# Level 2 Data - F 31-50 - Integer Optimization - With Category Constraints
#                 ID                                                Description  \
# 240    41570144107                        Blue Diamond® Honey Roasted Almonds
# 252    41570110232                       Blue Diamond® Lightly Salted Almonds
# 1661   38000016219  Kellogg's Special K Original Breakfast Cereal Family Size
# 2531   11110831415                Kroger® Pineapple Chunks in Pineapple Juice
# 2544   11110896650                        Kroger® Whole Berry Cranberry Sauce
# 2560   11110802507                      Kroger® No Salt Added Cut Green Beans
# 2626  884395207721                                     Sun Vista® Pinto Beans
# 2770   50000415175   Carnation Breakfast Essentials Rich Milk Chocolate Drink
# 3094   27000500101                             Hunt's Four Cheese Pasta Sauce
# 4683  715141729283                      Eggland's Best Extra Large White Eggs
# 4741   11110850058                                  Kroger® Spaghetti Noodles
# 5006   71430009765                                               Dole Spinach
# 5588   16000156432            Honey Nut Cheerios Gluten Free Breakfast Cereal
# 5977  736547571153                              Roth® Original Havarti Cheese
# 6078   72392930968                              Flavor Ice Giant Freezer Pops
#
#                          branded_food_category  Price per Serving  Amount
# 240   Popcorn, Peanuts, Seeds & Related Snacks               0.62     1.0
# 252   Popcorn, Peanuts, Seeds & Related Snacks               1.29     1.0
# 1661                                    Cereal               0.61     1.0
# 2531                              Canned Fruit               0.28     1.0
# 2544                              Canned Fruit               0.26     1.0
# 2560                         Canned Vegetables               0.25     1.0
# 2626                    Canned & Bottled Beans               0.03     1.0
# 2770                                     Candy               1.33     2.0
# 3094             Prepared Pasta & Pizza Sauces               0.22     1.0
# 4683                    Eggs & Egg Substitutes               0.30     1.0
# 4741                     Pasta by Shape & Type               0.12     1.0
# 5006           Pre-Packaged Fruit & Vegetables               0.86     1.0
# 5588                                    Cereal               0.29     1.0
# 5977                                    Cheese               0.05     1.0
# 6078                 Ice Cream & Frozen Yogurt               0.09     2.0

# %%
print("Level 2 Data - M 31-50 - Integer Optimization - With Category Constraints")
pd.DataFrame(level_2_int_res['M 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'Amount']]
# Out:
# Level 2 Data - M 31-50 - Integer Optimization - With Category Constraints
#                 ID                                                Description  \
# 240    41570144107                        Blue Diamond® Honey Roasted Almonds
# 252    41570110232                       Blue Diamond® Lightly Salted Almonds
# 1661   38000016219  Kellogg's Special K Original Breakfast Cereal Family Size
# 2544   11110896650                        Kroger® Whole Berry Cranberry Sauce
# 2626  884395207721                                     Sun Vista® Pinto Beans
# 2770   50000415175   Carnation Breakfast Essentials Rich Milk Chocolate Drink
# 3874   36200014943              Ragu Chunky Tomato Garlic & Onion Pasta Sauce
# 4229   27331000387                          La Banderita White Corn Tortillas
# 4683  715141729283                      Eggland's Best Extra Large White Eggs
# 4741   11110850058                                  Kroger® Spaghetti Noodles
# 5006   71430009765                                               Dole Spinach
# 5310  725342281039                            Muir Glen™ Organic Tomato Puree
# 5588   16000156432            Honey Nut Cheerios Gluten Free Breakfast Cereal
# 5977  736547571153                              Roth® Original Havarti Cheese
# 6078   72392930968                              Flavor Ice Giant Freezer Pops
#
#                          branded_food_category  Price per Serving  Amount
# 240   Popcorn, Peanuts, Seeds & Related Snacks               0.62     1.0
# 252   Popcorn, Peanuts, Seeds & Related Snacks               1.29     1.0
# 1661                                    Cereal               0.61     1.0
# 2544                              Canned Fruit               0.26     3.0
# 2626                    Canned & Bottled Beans               0.03     1.0
# 2770                                     Candy               1.33     2.0
# 3874             Prepared Pasta & Pizza Sauces               0.35     1.0
# 4229                      Mexican Dinner Mixes               0.12     1.0
# 4683                    Eggs & Egg Substitutes               0.30     1.0
# 4741                     Pasta by Shape & Type               0.12     1.0
# 5006           Pre-Packaged Fruit & Vegetables               0.86     1.0
# 5310            Vegetables  Prepared/Processed               0.27     2.0
# 5588                                    Cereal               0.29     1.0
# 5977                                    Cheese               0.05     1.0
# 6078                 Ice Cream & Frozen Yogurt               0.09     2.0

# %%
print(f'Level 2 F 31-50 Integer: ${level2_integer_fem_res}')
print(f'Level 2 M 31-50 Integer: ${level2_integer_male_res}')
# Out:
# Level 2 F 31-50 Integer: $8.02
# Level 2 M 31-50 Integer: $8.8

# %%
df = pd.DataFrame(level_2_int_res['M 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'serving_size', 'Size', 'Amount']]
df['Model'] = 'Level 2 - M 31-50 - Integer - With Category Constraints'
original_baskets_df = original_baskets_df.append(df)

df = pd.DataFrame(level_2_int_res['F 31-50'])[['ID', 'Description', 'branded_food_category', 'Price per Serving', 'serving_size', 'Size', 'Amount']]
df['Model'] = 'Level 2 - F 31-50 - Integer - With Category Constraints'
original_baskets_df = original_baskets_df.append(df)

original_baskets_df.to_csv('Original Baskets.csv', index=False)

# %%
unique_prods = original_baskets_df[['ID', 'Description']]
unique_prods = unique_prods.drop_duplicates()
unique_prods.to_csv('Unique Products - FNDDS.csv', index=False)

# %%
end_time = time.time()

print(f'Total Running Time So Far: {(end_time-start_time)//60} minutes {(end_time-start_time)%60} seconds')
# Out:
# Total Running Time So Far: 0.0 minutes 50.91911172866821 seconds

# %% [markdown]
# ## Let's try to do all the same things we did earlier but threaded except not threaded anymore

# %% [markdown]
# ### Vary Nutrient Constraints

# %%
sodium_range = np.linspace(1000, 5000, 41)
sodium_results = {}
models = ['M 31-50', 'F 31-50']

for na in sodium_range:
    opt = NutOptimizer(data=level_2_dat)
    opt.load_constraints_json(fp)
    
    add_category_constraints(opt, include_mins, max_per_category)
    # Vary Constraints as necessary
    for model in models:
        opt.update_constraint(model, 'Sodium, Na', 'max', na)
    # Do the optimization
    for model in models:
        opt.optimize_one(model, 'Price per Serving', 'INTEGER', verbose=False, timeout=3600)        
    
    # Record the results
    for model in models:
        if model not in sodium_results:
            sodium_results[model] = {}
            sodium_results[model]['cost'] = {}
            sodium_results[model]['prods'] = {}
        sodium_results[model]['cost'][na] = opt.get_one_optimal_value(model, 'Price per Serving')
        sodium_results[model]['prods'][na] = opt.get_one_result(model)

# %%
sodium_costs = {}

for model in ['M 31-50', 'F 31-50']:
    sodium_costs[model] = []
    for i in sodium_range:
        sodium_costs[model].append(sodium_results[model]['cost'][i])

# %%
plt.plot(sodium_range, sodium_costs['M 31-50'], color='xkcd:blue', label='Male 31-50', linestyle='solid')
plt.plot(sodium_range, sodium_costs['F 31-50'], color='xkcd:green', label='Female 31-50', linestyle='dashed')
plt.axvline(x=2300, color='xkcd:black')
plt.legend()
plt.title("Sodium")
plt.xlabel("Maximum Sodium (mg)")
plt.ylabel("Price ($)")
plt.savefig('sodium.png', dpi=300)
plt.show()

# %%
print(sodium_costs)
# Out:
# {'M 31-50': [11.440000000000003, 10.720000000000002, 10.39, 10.009999999999998, 9.869999999999997, 9.579999999999998, 9.37, 9.239999999999998, 9.11, 9.04, 8.959999999999999, 8.879999999999999, 8.8, 8.8, 8.729999999999999, 8.729999999999999, 8.66, 8.639999999999999, 8.6, 8.58, 8.54, 8.52, 8.499999999999998, 8.499999999999998, 8.5, 8.479999999999999, 8.48, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999, 8.479999999999999], 'F 31-50': [9.98, 9.33, 9.159999999999998, 8.899999999999999, 8.670000000000002, 8.54, 8.41, 8.26, 8.26, 8.219999999999999, 8.17, 8.08, 8.06, 8.02, 7.9399999999999995, 7.9399999999999995, 7.9, 7.879999999999999, 7.799999999999999, 7.7799999999999985, 7.749999999999999, 7.749999999999999, 7.719999999999999, 7.719999999999999, 7.719999999999999, 7.72, 7.719999999999999, 7.72, 7.72, 7.72, 7.72, 7.72, 7.719999999999999, 7.719999999999999, 7.719999999999999, 7.72, 7.72, 7.72, 7.72, 7.72, 7.72]}

# %%
end_time = time.time()

print(f'Total Running Time So Far: {(end_time-start_time)//60} minutes {(end_time-start_time)%60} seconds')
# Out:
# Total Running Time So Far: 14.0 minutes 36.68031454086304 seconds

# %%
satfat_range = np.linspace(0, 350, 36)
satfat_results = {}

for satfat in satfat_range:
    opt = NutOptimizer(data=level_2_dat)
    opt.load_constraints_json(fp)
    
    add_category_constraints(opt, include_mins, max_per_category)
    # Vary Constraints as necessary
    for model in models:
        opt.update_constraint(model, 'Fatty acids, total saturated', 'max', satfat)
    # Do the optimization
    for model in models:
        opt.optimize_one(model, 'Price per Serving', 'INTEGER', verbose=False, timeout=3600)        
    
    # Record the results
    for model in models:
        if model not in satfat_results:
            satfat_results[model] = {}
            satfat_results[model]['cost'] = {}
            satfat_results[model]['prods'] = {}
        satfat_results[model]['cost'][satfat] = opt.get_one_optimal_value(model, 'Price per Serving')
        satfat_results[model]['prods'][satfat] = opt.get_one_result(model)

# %%
satfat_costs = {}

for model in ['M 31-50', 'F 31-50']:
    satfat_costs[model] = []
    for i in satfat_range:
        satfat_costs[model].append(satfat_results[model]['cost'][i])

# %%
plt.plot(satfat_range, satfat_costs['M 31-50'], color='xkcd:blue', label='Male 31-50', linestyle='solid')
plt.plot(satfat_range, satfat_costs['F 31-50'], color='xkcd:green', label='Female 31-50', linestyle='dashed')
plt.axvline(x=180, color='xkcd:green', linestyle='dashed')
plt.axvline(x=220, color='xkcd:blue', linestyle='solid')
plt.legend()
plt.title("Saturated Fat")
plt.xlabel("Maximum Saturated Fat (kcal)")
plt.ylabel("Price ($)")
plt.savefig('satfat.png', dpi=300)
plt.show()

# %%
end_time = time.time()

print(f'Total Running Time So Far: {(end_time-start_time)//60} minutes {(end_time-start_time)%60} seconds')
# Out:
# Total Running Time So Far: 27.0 minutes 27.799599409103394 seconds

# %%
sugar_range = np.linspace(50, 400, 36)
sugar_results = {}

for sugar in sugar_range:
    opt = NutOptimizer(data=level_2_dat)
    opt.load_constraints_json(fp)
    
    add_category_constraints(opt, include_mins, max_per_category)
    # Vary Constraints as necessary
    for model in models:
        opt.update_constraint(model, 'Sugars, added', 'max', sugar)
    # Do the optimization
    for model in models:
        opt.optimize_one(model, 'Price per Serving', 'INTEGER', verbose=False, timeout=3600)        
    
    # Record the results
    for model in models:
        if model not in sugar_results:
            sugar_results[model] = {}
            sugar_results[model]['cost'] = {}
            sugar_results[model]['prods'] = {}
        sugar_results[model]['cost'][sugar] = opt.get_one_optimal_value(model, 'Price per Serving')
        sugar_results[model]['prods'][sugar] = opt.get_one_result(model)

# %%
sugar_costs = {}

for model in ['M 31-50', 'F 31-50']:
    sugar_costs[model] = []
    for i in sugar_range:
        sugar_costs[model].append(sugar_results[model]['cost'][i])

# %%
plt.plot(sugar_range, sugar_costs['M 31-50'], color='xkcd:blue', label='Male 31-50', linestyle='solid')
plt.plot(sugar_range, sugar_costs['F 31-50'], color='xkcd:green', label='Female 31-50', linestyle='dashed')
plt.axvline(x=180, color='xkcd:green', linestyle='dashed')
plt.axvline(x=220, color='xkcd:blue', linestyle='solid')
plt.legend()
plt.title("Added Sugar")
plt.xlabel("Maximum Total Added Sugar (kcal)")
plt.ylabel("Price ($)")
plt.savefig('sugar.png', dpi=300)
plt.show()

# %%
end_time = time.time()

print(f'Total Running Time So Far: {(end_time-start_time)//60} minutes {(end_time-start_time)%60} seconds')
# Out:
# Total Running Time So Far: 39.0 minutes 30.112244129180908 seconds

# %% [markdown]
# # Table with Changing Tolerances

# %%
def color(val):
    if not isinstance(val, bool):
        return 'color: black'
    if val:
        return 'color: blue'
    return 'color: red'

# %% [markdown]
# ## Level 2 Data

# %%
level_2_opt.load_constraints_json(fp)
add_category_constraints(level_2_opt, include_mins, max_per_category)

# %%
tolerances = [0.0, .025, 0.05, 0.1, 0.15, 0.20, 0.25, 0.30, 0.40, 0.50]

# %%
level_2_original_const = level_2_opt.constraints
adjust_min = True
adjust_max = True

level_2_cost_dict = {}

for model in ['M 31-50', 'F 31-50']:
    level_2_cost_dict[model] = {}
    for tolerance in tolerances:
        level_2_cost_dict[model][tolerance] = {}
        for const in level_2_original_const[model]:
            if const in cats['Final Category'].unique() or const == 'Energy - kcal':
                continue
            for const_type in level_2_original_const[model][const]:
                if const_type == 'max':
                    if adjust_max:
                        level_2_opt.update_constraint(model, const, const_type, level_2_original_const[model][const][const_type]*(1+tolerance))
                elif const_type == 'min':
                    if adjust_min:
                        level_2_opt.update_constraint(model, const, const_type, level_2_original_const[model][const][const_type]*(1-tolerance))
        
        level_2_opt.optimize_one(model, 'Price per Serving', verbose=False, var_type='INTEGER')
        level_2_cost_dict[model][tolerance]['Cost'] = level_2_opt.get_one_optimal_value(model, 'Price per Serving')
        for nutrient in level_2_original_const[model]:
            if nutrient not in cats['Final Category'].unique():
                level_2_cost_dict[model][tolerance][nutrient] = level_2_opt.get_one_optimal_value(model, nutrient)

        level_2_opt.load_constraints_json(fp)
        add_category_constraints(level_2_opt, True, 2)

# %%
level_2_tf_cost_dict = {}

for model in ['M 31-50', 'F 31-50']:
    level_2_tf_cost_dict[model] = {}
    for tolerance in level_2_cost_dict[model]:
        level_2_tf_cost_dict[model][tolerance] = {}
        for const in level_2_cost_dict[model][tolerance]:
            if const == 'Cost': 
                level_2_tf_cost_dict[model][tolerance][const] = level_2_cost_dict[model][tolerance][const]
                continue
            if const == 'Energy - kcal':
                continue
            mini = level_2_original_const[model][const].get('min') if level_2_original_const[model][const].get('min') else 0
            optimal = level_2_cost_dict[model][tolerance][const]
            maxi = level_2_original_const[model][const].get('max') if level_2_original_const[model][const].get('max') else np.inf
            level_2_tf_cost_dict[model][tolerance][const] = mini <= optimal <= maxi

# %%
print("F 31-50 Level 2")
df = pd.DataFrame(level_2_tf_cost_dict['F 31-50'])
df.style.applymap(color)
# Out:
# F 31-50 Level 2
# <style type="text/css">
# #T_35817_row0_col0, #T_35817_row0_col1, #T_35817_row0_col2, #T_35817_row0_col3, #T_35817_row0_col4, #T_35817_row0_col5, #T_35817_row0_col6, #T_35817_row0_col7, #T_35817_row0_col8, #T_35817_row0_col9 {
#   color: black;
# }
# #T_35817_row1_col0, #T_35817_row1_col1, #T_35817_row1_col2, #T_35817_row1_col3, #T_35817_row1_col4, #T_35817_row1_col5, #T_35817_row1_col6, #T_35817_row1_col7, #T_35817_row1_col8, #T_35817_row1_col9, #T_35817_row2_col0, #T_35817_row2_col1, #T_35817_row2_col2, #T_35817_row2_col3, #T_35817_row2_col4, #T_35817_row2_col5, #T_35817_row2_col6, #T_35817_row2_col7, #T_35817_row2_col8, #T_35817_row2_col9, #T_35817_row3_col0, #T_35817_row3_col4, #T_35817_row3_col5, #T_35817_row3_col6, #T_35817_row3_col7, #T_35817_row3_col8, #T_35817_row3_col9, #T_35817_row4_col0, #T_35817_row4_col1, #T_35817_row4_col2, #T_35817_row4_col3, #T_35817_row4_col4, #T_35817_row4_col5, #T_35817_row4_col6, #T_35817_row4_col7, #T_35817_row4_col8, #T_35817_row4_col9, #T_35817_row5_col0, #T_35817_row5_col1, #T_35817_row5_col2, #T_35817_row5_col3, #T_35817_row5_col4, #T_35817_row5_col6, #T_35817_row6_col0, #T_35817_row6_col1, #T_35817_row6_col2, #T_35817_row6_col3, #T_35817_row6_col4, #T_35817_row6_col5, #T_35817_row6_col6, #T_35817_row6_col7, #T_35817_row6_col8, #T_35817_row6_col9, #T_35817_row7_col0, #T_35817_row7_col1, #T_35817_row7_col2, #T_35817_row7_col3, #T_35817_row7_col4, #T_35817_row7_col5, #T_35817_row7_col6, #T_35817_row7_col7, #T_35817_row7_col8, #T_35817_row7_col9, #T_35817_row8_col0, #T_35817_row8_col1, #T_35817_row8_col2, #T_35817_row8_col3, #T_35817_row8_col4, #T_35817_row8_col8, #T_35817_row9_col0, #T_35817_row9_col1, #T_35817_row9_col2, #T_35817_row9_col4, #T_35817_row9_col5, #T_35817_row9_col6, #T_35817_row9_col7, #T_35817_row10_col0, #T_35817_row10_col1, #T_35817_row10_col2, #T_35817_row10_col3, #T_35817_row10_col4, #T_35817_row10_col5, #T_35817_row10_col6, #T_35817_row10_col7, #T_35817_row10_col8, #T_35817_row10_col9, #T_35817_row11_col0, #T_35817_row11_col1, #T_35817_row11_col2, #T_35817_row11_col3, #T_35817_row11_col4, #T_35817_row12_col0, #T_35817_row12_col1, #T_35817_row13_col0, #T_35817_row13_col1, #T_35817_row13_col2, #T_35817_row13_col6, #T_35817_row13_col7, #T_35817_row14_col0, #T_35817_row14_col1, #T_35817_row14_col2, #T_35817_row14_col6, #T_35817_row14_col7, #T_35817_row14_col8, #T_35817_row14_col9, #T_35817_row15_col0, #T_35817_row15_col1, #T_35817_row15_col2, #T_35817_row15_col3, #T_35817_row15_col5, #T_35817_row16_col0, #T_35817_row16_col1, #T_35817_row16_col2, #T_35817_row16_col3, #T_35817_row16_col4, #T_35817_row16_col5, #T_35817_row16_col6, #T_35817_row16_col7, #T_35817_row16_col8, #T_35817_row16_col9, #T_35817_row17_col0, #T_35817_row17_col1, #T_35817_row17_col2, #T_35817_row17_col4, #T_35817_row18_col0, #T_35817_row19_col0, #T_35817_row19_col1, #T_35817_row19_col2, #T_35817_row19_col4, #T_35817_row19_col5, #T_35817_row19_col7, #T_35817_row20_col0, #T_35817_row20_col1, #T_35817_row20_col2, #T_35817_row20_col3, #T_35817_row20_col4, #T_35817_row20_col5, #T_35817_row20_col6, #T_35817_row20_col7, #T_35817_row20_col8, #T_35817_row20_col9, #T_35817_row21_col0, #T_35817_row21_col1, #T_35817_row21_col2, #T_35817_row21_col3, #T_35817_row21_col4, #T_35817_row21_col5, #T_35817_row21_col6, #T_35817_row21_col7, #T_35817_row21_col8, #T_35817_row21_col9, #T_35817_row22_col0, #T_35817_row22_col1, #T_35817_row22_col2, #T_35817_row22_col3, #T_35817_row22_col4, #T_35817_row22_col5, #T_35817_row22_col6, #T_35817_row22_col7, #T_35817_row22_col9, #T_35817_row23_col0, #T_35817_row23_col1, #T_35817_row23_col2, #T_35817_row23_col3, #T_35817_row23_col4, #T_35817_row23_col5, #T_35817_row23_col6, #T_35817_row23_col7, #T_35817_row23_col8, #T_35817_row23_col9, #T_35817_row24_col0, #T_35817_row24_col1, #T_35817_row24_col2, #T_35817_row25_col0, #T_35817_row25_col1, #T_35817_row25_col2, #T_35817_row25_col3, #T_35817_row25_col4, #T_35817_row25_col5, #T_35817_row25_col6, #T_35817_row26_col0, #T_35817_row26_col1, #T_35817_row26_col2, #T_35817_row26_col3, #T_35817_row26_col4, #T_35817_row26_col5, #T_35817_row26_col6, #T_35817_row26_col7, #T_35817_row26_col8, #T_35817_row26_col9, #T_35817_row27_col0, #T_35817_row27_col1, #T_35817_row27_col2, #T_35817_row27_col4, #T ...
#   color: blue;
# }
# #T_35817_row3_col1, #T_35817_row3_col2, #T_35817_row3_col3, #T_35817_row5_col5, #T_35817_row5_col7, #T_35817_row5_col8, #T_35817_row5_col9, #T_35817_row8_col5, #T_35817_row8_col6, #T_35817_row8_col7, #T_35817_row8_col9, #T_35817_row9_col3, #T_35817_row9_col8, #T_35817_row9_col9, #T_35817_row11_col5, #T_35817_row11_col6, #T_35817_row11_col7, #T_35817_row11_col8, #T_35817_row11_col9, #T_35817_row12_col2, #T_35817_row12_col3, #T_35817_row12_col4, #T_35817_row12_col5, #T_35817_row12_col6, #T_35817_row12_col7, #T_35817_row12_col8, #T_35817_row12_col9, #T_35817_row13_col3, #T_35817_row13_col4, #T_35817_row13_col5, #T_35817_row13_col8, #T_35817_row13_col9, #T_35817_row14_col3, #T_35817_row14_col4, #T_35817_row14_col5, #T_35817_row15_col4, #T_35817_row15_col6, #T_35817_row15_col7, #T_35817_row15_col8, #T_35817_row15_col9, #T_35817_row17_col3, #T_35817_row17_col5, #T_35817_row17_col6, #T_35817_row17_col7, #T_35817_row17_col8, #T_35817_row17_col9, #T_35817_row18_col1, #T_35817_row18_col2, #T_35817_row18_col3, #T_35817_row18_col4, #T_35817_row18_col5, #T_35817_row18_col6, #T_35817_row18_col7, #T_35817_row18_col8, #T_35817_row18_col9, #T_35817_row19_col3, #T_35817_row19_col6, #T_35817_row19_col8, #T_35817_row19_col9, #T_35817_row22_col8, #T_35817_row24_col3, #T_35817_row24_col4, #T_35817_row24_col5, #T_35817_row24_col6, #T_35817_row24_col7, #T_35817_row24_col8, #T_35817_row24_col9, #T_35817_row25_col7, #T_35817_row25_col8, #T_35817_row25_col9, #T_35817_row27_col3, #T_35817_row27_col6, #T_35817_row27_col7, #T_35817_row27_col8, #T_35817_row27_col9, #T_35817_row28_col3, #T_35817_row28_col5, #T_35817_row28_col6, #T_35817_row28_col7, #T_35817_row28_col8, #T_35817_row28_col9 {
#   color: red;
# }
# </style>
# <table id="T_35817_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.0</th>
#       <th class="col_heading level0 col1" >0.025</th>
#       <th class="col_heading level0 col2" >0.05</th>
#       <th class="col_heading level0 col3" >0.1</th>
#       <th class="col_heading level0 col4" >0.15</th>
#       <th class="col_heading level0 col5" >0.2</th>
#       <th class="col_heading level0 col6" >0.25</th>
#       <th class="col_heading level0 col7" >0.3</th>
#       <th class="col_heading level0 col8" >0.4</th>
#       <th class="col_heading level0 col9" >0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35817_level0_row0" class="row_heading level0 row0" >Cost</th>
#       <td id="T_35817_row0_col0" class="data row0 col0" >8.020000</td>
#       <td id="T_35817_row0_col1" class="data row0 col1" >7.940000</td>
#       <td id="T_35817_row0_col2" class="data row0 col2" >7.800000</td>
#       <td id="T_35817_row0_col3" class="data row0 col3" >6.990000</td>
#       <td id="T_35817_row0_col4" class="data row0 col4" >6.690000</td>
#       <td id="T_35817_row0_col5" class="data row0 col5" >6.020000</td>
#       <td id="T_35817_row0_col6" class="data row0 col6" >5.420000</td>
#       <td id="T_35817_row0_col7" class="data row0 col7" >5.110000</td>
#       <td id="T_35817_row0_col8" class="data row0 col8" >4.220000</td>
#       <td id="T_35817_row0_col9" class="data row0 col9" >3.530000</td>
#     </tr>
#     <tr>
#       <th id="T_35817_level0_row1" class="row_heading level0 row1" >Protein - cal</th>
#       <td id="T_35817_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_35817_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_35817_row1_col2" class="data row1 col2" >True</td>
#       <td id="T_35817_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_35817_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_35817_row1_col5" class="data

# %%
print("M 31-50 Level 2")
df = pd.DataFrame(level_2_tf_cost_dict['M 31-50'])
df.style.applymap(color)
# Out:
# M 31-50 Level 2
# <style type="text/css">
# #T_0992a_row0_col0, #T_0992a_row0_col1, #T_0992a_row0_col2, #T_0992a_row0_col3, #T_0992a_row0_col4, #T_0992a_row0_col5, #T_0992a_row0_col6, #T_0992a_row0_col7, #T_0992a_row0_col8, #T_0992a_row0_col9 {
#   color: black;
# }
# #T_0992a_row1_col0, #T_0992a_row1_col1, #T_0992a_row1_col2, #T_0992a_row1_col3, #T_0992a_row1_col4, #T_0992a_row1_col5, #T_0992a_row1_col6, #T_0992a_row1_col7, #T_0992a_row1_col8, #T_0992a_row1_col9, #T_0992a_row2_col0, #T_0992a_row2_col1, #T_0992a_row2_col2, #T_0992a_row2_col3, #T_0992a_row2_col4, #T_0992a_row2_col5, #T_0992a_row2_col6, #T_0992a_row2_col7, #T_0992a_row2_col8, #T_0992a_row2_col9, #T_0992a_row3_col0, #T_0992a_row3_col1, #T_0992a_row3_col2, #T_0992a_row3_col3, #T_0992a_row3_col5, #T_0992a_row3_col7, #T_0992a_row4_col0, #T_0992a_row4_col1, #T_0992a_row4_col2, #T_0992a_row4_col3, #T_0992a_row4_col4, #T_0992a_row4_col5, #T_0992a_row4_col6, #T_0992a_row4_col7, #T_0992a_row4_col8, #T_0992a_row4_col9, #T_0992a_row5_col0, #T_0992a_row5_col1, #T_0992a_row5_col2, #T_0992a_row5_col5, #T_0992a_row5_col6, #T_0992a_row5_col7, #T_0992a_row5_col8, #T_0992a_row6_col0, #T_0992a_row6_col1, #T_0992a_row6_col2, #T_0992a_row6_col5, #T_0992a_row6_col7, #T_0992a_row6_col8, #T_0992a_row6_col9, #T_0992a_row7_col0, #T_0992a_row7_col1, #T_0992a_row7_col2, #T_0992a_row7_col3, #T_0992a_row7_col4, #T_0992a_row7_col5, #T_0992a_row7_col6, #T_0992a_row7_col7, #T_0992a_row7_col8, #T_0992a_row7_col9, #T_0992a_row8_col0, #T_0992a_row8_col1, #T_0992a_row8_col2, #T_0992a_row8_col5, #T_0992a_row8_col6, #T_0992a_row9_col0, #T_0992a_row9_col1, #T_0992a_row9_col2, #T_0992a_row9_col3, #T_0992a_row9_col4, #T_0992a_row9_col5, #T_0992a_row9_col6, #T_0992a_row9_col7, #T_0992a_row9_col8, #T_0992a_row10_col0, #T_0992a_row10_col1, #T_0992a_row10_col2, #T_0992a_row10_col3, #T_0992a_row10_col4, #T_0992a_row10_col5, #T_0992a_row10_col6, #T_0992a_row10_col7, #T_0992a_row10_col8, #T_0992a_row10_col9, #T_0992a_row11_col0, #T_0992a_row11_col1, #T_0992a_row11_col5, #T_0992a_row12_col0, #T_0992a_row12_col1, #T_0992a_row12_col5, #T_0992a_row12_col6, #T_0992a_row13_col0, #T_0992a_row14_col0, #T_0992a_row14_col8, #T_0992a_row15_col0, #T_0992a_row15_col1, #T_0992a_row15_col2, #T_0992a_row15_col3, #T_0992a_row15_col4, #T_0992a_row15_col5, #T_0992a_row16_col0, #T_0992a_row16_col1, #T_0992a_row16_col2, #T_0992a_row16_col3, #T_0992a_row16_col4, #T_0992a_row16_col5, #T_0992a_row16_col6, #T_0992a_row16_col7, #T_0992a_row16_col8, #T_0992a_row16_col9, #T_0992a_row17_col0, #T_0992a_row17_col1, #T_0992a_row17_col2, #T_0992a_row17_col3, #T_0992a_row17_col4, #T_0992a_row18_col0, #T_0992a_row19_col0, #T_0992a_row19_col1, #T_0992a_row19_col2, #T_0992a_row19_col3, #T_0992a_row19_col4, #T_0992a_row19_col5, #T_0992a_row19_col6, #T_0992a_row19_col7, #T_0992a_row20_col0, #T_0992a_row20_col1, #T_0992a_row20_col2, #T_0992a_row20_col3, #T_0992a_row20_col4, #T_0992a_row20_col5, #T_0992a_row20_col7, #T_0992a_row20_col8, #T_0992a_row20_col9, #T_0992a_row21_col0, #T_0992a_row21_col1, #T_0992a_row21_col2, #T_0992a_row21_col3, #T_0992a_row21_col4, #T_0992a_row21_col5, #T_0992a_row21_col6, #T_0992a_row21_col7, #T_0992a_row21_col8, #T_0992a_row21_col9, #T_0992a_row22_col0, #T_0992a_row22_col1, #T_0992a_row22_col2, #T_0992a_row22_col3, #T_0992a_row22_col4, #T_0992a_row22_col5, #T_0992a_row22_col6, #T_0992a_row22_col8, #T_0992a_row22_col9, #T_0992a_row23_col0, #T_0992a_row23_col1, #T_0992a_row23_col2, #T_0992a_row23_col3, #T_0992a_row23_col4, #T_0992a_row23_col5, #T_0992a_row23_col6, #T_0992a_row23_col7, #T_0992a_row23_col8, #T_0992a_row23_col9, #T_0992a_row24_col0, #T_0992a_row24_col1, #T_0992a_row24_col2, #T_0992a_row25_col0, #T_0992a_row25_col1, #T_0992a_row25_col2, #T_0992a_row25_col3, #T_0992a_row25_col4, #T_0992a_row25_col5, #T_0992a_row25_col6, #T_0992a_row25_col7, #T_0992a_row25_col8, #T_0992a_row26_col0, #T_0992a_row26_col1, #T_0992a_row26_col2, #T_0992a_row26_col3, #T_0992a_row26_col4, #T_0992a_row26_col5, #T_0992a_row26_col6, #T_0992a_row26_col7, #T_0992a_row26_col8, #T_0992a_row26_col9, #T_0992a_row27_col0, #T_0992a_row27_col1, #T_0992a_row27_col2, #T_0992a_row27_col3, #T_0992a_row27_col4, #T_0992a_row27_col5, #T_0992a_row27_col6, #T_0992a_row27_col7, #T_0992a_row28_col0, #T_0992a_row28_col1,  ...
#   color: blue;
# }
# #T_0992a_row3_col4, #T_0992a_row3_col6, #T_0992a_row3_col8, #T_0992a_row3_col9, #T_0992a_row5_col3, #T_0992a_row5_col4, #T_0992a_row5_col9, #T_0992a_row6_col3, #T_0992a_row6_col4, #T_0992a_row6_col6, #T_0992a_row8_col3, #T_0992a_row8_col4, #T_0992a_row8_col7, #T_0992a_row8_col8, #T_0992a_row8_col9, #T_0992a_row9_col9, #T_0992a_row11_col2, #T_0992a_row11_col3, #T_0992a_row11_col4, #T_0992a_row11_col6, #T_0992a_row11_col7, #T_0992a_row11_col8, #T_0992a_row11_col9, #T_0992a_row12_col2, #T_0992a_row12_col3, #T_0992a_row12_col4, #T_0992a_row12_col7, #T_0992a_row12_col8, #T_0992a_row12_col9, #T_0992a_row13_col1, #T_0992a_row13_col2, #T_0992a_row13_col3, #T_0992a_row13_col4, #T_0992a_row13_col5, #T_0992a_row13_col6, #T_0992a_row13_col7, #T_0992a_row13_col8, #T_0992a_row13_col9, #T_0992a_row14_col1, #T_0992a_row14_col2, #T_0992a_row14_col3, #T_0992a_row14_col4, #T_0992a_row14_col5, #T_0992a_row14_col6, #T_0992a_row14_col7, #T_0992a_row14_col9, #T_0992a_row15_col6, #T_0992a_row15_col7, #T_0992a_row15_col8, #T_0992a_row15_col9, #T_0992a_row17_col5, #T_0992a_row17_col6, #T_0992a_row17_col7, #T_0992a_row17_col8, #T_0992a_row17_col9, #T_0992a_row18_col1, #T_0992a_row18_col2, #T_0992a_row18_col3, #T_0992a_row18_col4, #T_0992a_row18_col5, #T_0992a_row18_col6, #T_0992a_row18_col7, #T_0992a_row18_col8, #T_0992a_row18_col9, #T_0992a_row19_col8, #T_0992a_row19_col9, #T_0992a_row20_col6, #T_0992a_row22_col7, #T_0992a_row24_col3, #T_0992a_row24_col4, #T_0992a_row24_col5, #T_0992a_row24_col6, #T_0992a_row24_col7, #T_0992a_row24_col8, #T_0992a_row24_col9, #T_0992a_row25_col9, #T_0992a_row27_col8, #T_0992a_row27_col9, #T_0992a_row28_col7, #T_0992a_row28_col8, #T_0992a_row28_col9 {
#   color: red;
# }
# </style>
# <table id="T_0992a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.0</th>
#       <th class="col_heading level0 col1" >0.025</th>
#       <th class="col_heading level0 col2" >0.05</th>
#       <th class="col_heading level0 col3" >0.1</th>
#       <th class="col_heading level0 col4" >0.15</th>
#       <th class="col_heading level0 col5" >0.2</th>
#       <th class="col_heading level0 col6" >0.25</th>
#       <th class="col_heading level0 col7" >0.3</th>
#       <th class="col_heading level0 col8" >0.4</th>
#       <th class="col_heading level0 col9" >0.5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0992a_level0_row0" class="row_heading level0 row0" >Cost</th>
#       <td id="T_0992a_row0_col0" class="data row0 col0" >8.800000</td>
#       <td id="T_0992a_row0_col1" class="data row0 col1" >8.730000</td>
#       <td id="T_0992a_row0_col2" class="data row0 col2" >8.650000</td>
#       <td id="T_0992a_row0_col3" class="data row0 col3" >8.200000</td>
#       <td id="T_0992a_row0_col4" class="data row0 col4" >7.500000</td>
#       <td id="T_0992a_row0_col5" class="data row0 col5" >7.230000</td>
#       <td id="T_0992a_row0_col6" class="data row0 col6" >6.780000</td>
#       <td id="T_0992a_row0_col7" class="data row0 col7" >6.490000</td>
#       <td id="T_0992a_row0_col8" class="data row0 col8" >4.830000</td>
#       <td id="T_0992a_row0_col9" class="data row0 col9" >4.190000</td>
#     </tr>
#     <tr>
#       <th id="T_0992a_level0_row1" class="row_heading level0 row1" >Protein - cal</th>
#       <td id="T_0992a_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_0992a_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_0992a_row1_col2" class="data row1 col2" >True</td>
#       <td id="T_0992a_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_0992a_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_0992a_row1_col5" class="data

# %%
rows = dat.shape[0]
for col in level_2_tf_cost_dict['M 31-50'][0]:
    if col == 'Cost':
        continue
    print(f'{col}: {round(100*(dat[col]==0).sum()/rows,2)}%')
# Out:
# Protein - cal: 26.66%
# Protein - g: 26.66%
# Carb - cal: 10.28%
# Total Carbohydrate: 10.28%
# Fiber, total dietary: 44.56%
# Sugars, added: 65.8%
# Total lipid (fat): 30.79%
# Fatty acids, total saturated: 44.29%
# Calcium, Ca: 41.27%
# Iron, Fe: 40.24%
# Magnesium, Mg: 96.17%
# Phosphorus, P: 96.03%
# Potassium, K: 47.75%
# Sodium, Na: 12.09%
# Zinc, Zn: 97.17%
# Vitamin A, IU: 87.26%
# Vitamin E: 99.15%
# Vitamin D (D2 + D3), International Units: 97.68%
# Vitamin C, total ascorbic acid: 85.25%
# Thiamin: 97.17%
# Riboflavin: 93.94%
# Niacin: 92.27%
# Vitamin K (phylloquinone): 99.39%
# Folic acid: 96.81%
# Vitamin B-6: 95.23%
# Vitamin B-12: 96.0%
# Protein Foods_wt_in_g: 92.66%
# Grains_wt_in_g: 92.54%

# %%
end_time = time.time()

print(f'Total Notebook Running Time: {(end_time-start_time)//60} minutes {(end_time-start_time)%60} seconds')
# Out:
# Total Notebook Running Time: 43.0 minutes 4.808959007263184 seconds

# %%
# from PIL import Image
# from io import BytesIO
# import imageio as iio

# file = 'dataset.png'
# img = Image.open(file)
# img.convert("RGB").save(f"{file}", "PNG", dpi=(300,300))
